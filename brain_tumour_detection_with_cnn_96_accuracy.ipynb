# %% [markdown]
# <a href="https://colab.research.google.com/github/kosarsadoughi/CNN/blob/main/brain_tumour_detection_with_cnn_96_accuracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installing dependencies for preprocessing of images

# %%
# !pip install imutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imutils in /usr/local/lib/python3.9/dist-packages (0.5.4)

# %% [markdown]
# ### Helper Functions

# %%
import numpy as np 
import pandas as pd 
import os
from os import listdir
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import imutils    

from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Conv2D,Input,ZeroPadding2D,BatchNormalization,Flatten,Activation,Dense,MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle #shuffling the data improves the model

# %%
from google.colab import drive
drive.mount('../content/drive')
# Out:
# Mounted at ../content/drive

# %%
# !unzip '/content/drive/MyDrive/KosarSadoughi/Kaggle/brain-mri-images-for-brain-tumor-detection.zip' -d '/content/drive/MyDrive/KosarSadoughi/Dataset'
# Out:
# Archive:  /content/drive/MyDrive/KosarSadoughi/Kaggle/brain-mri-images-for-brain-tumor-detection.zip
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/1 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/10 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/11 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/12 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/13 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/14 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/15 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/17 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/18 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/19 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/2 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/20 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/21 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/22 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/23 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/24 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/25 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/26 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/27 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/28 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/29 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/3 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/30 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/31 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/32 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/33 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/34 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/35 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/36 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/37 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/38 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/39 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/4 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/40 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/41 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/42 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/43 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/44no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/45 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/46 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/47 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/48 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/49 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/5 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/50 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/6 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/7 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/8 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/9 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N1.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N16.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N19.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N2.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N20.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N22.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N26.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N5.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/N6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No12.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No13.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No14.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No16.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No18.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No19.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No20.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/No22.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 1.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 10.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 100.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 2.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 4.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 5.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 7.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 8.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 89.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 9.png
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 90.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 91.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 92.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 923.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 94.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 95.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 96.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 97.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 98.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no 99.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/no/no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y1.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y10.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y100.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y101.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y102.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y103.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y104.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y105.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y106.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y107.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y108.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y109.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y111.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y112.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y113.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y114.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y115.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y116.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y117.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y12.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y120.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y13.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y14.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y146.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y147.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y148.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y153.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y154.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y155.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y156.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y157.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y158.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y159.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y16.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y160.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y161.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y162.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y163.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y164.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y165.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y166.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y167.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y168.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y169.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y170.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y18.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y180.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y181.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y182.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y183.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y184.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y185.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y186.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y187.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y188.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y19.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y192.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y193.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y194.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y195.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y2.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y20.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y22.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y23.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y24.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y242.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y243.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y244.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y245.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y246.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y247.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y248.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y249.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y25.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y250.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y251.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y252.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y253.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y254.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y255.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y256.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y257.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y258.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y259.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y26.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y27.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y28.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y29.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y30.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y31.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y32.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y33.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y34.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y35.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y36.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y37.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y38.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y39.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y4.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y40.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y41.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y42.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y44.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y45.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y46.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y47.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y49.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y50.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y51.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y52.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y53.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y54.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y55.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y56.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y58.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y59.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y60.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y61.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y62.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y65.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y66.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y67.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y69.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y7.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y70.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y71.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y73.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y74.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y75.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y76.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y77.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y78.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y79.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y8.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y81.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y82.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y85.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y86.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y89.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y9.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y90.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y91.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y92.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y92.png
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y95.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y96.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y97.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y98.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/yes/Y99.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/1 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/10 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/11 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/12 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/13 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/14 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/15 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/17 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/18 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/19 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/2 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/20 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/21 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/22 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/23 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/24 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/25 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/26 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/27 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/28 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/29 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/3 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/30 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/31 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/32 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/33 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/34 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/35 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/36 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/37 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/38 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/39 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/4 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/40 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/41 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/42 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/43 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/44no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/45 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/46 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/47 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/48 no.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/49 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/5 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/50 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/6 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/7 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/8 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/9 no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N1.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N16.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N19.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N2.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N20.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N22.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N26.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N5.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/N6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No12.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No13.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No14.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No16.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No18.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No19.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No20.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/No22.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 1.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 10.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 100.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 2.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 4.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 5.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 7.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 8.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 89.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 9.png
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 90.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 91.jpeg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 92.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 923.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 94.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 95.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 96.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 97.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 98.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no 99.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/no/no.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y1.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y10.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y100.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y101.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y102.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y103.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y104.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y105.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y106.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y107.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y108.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y109.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y11.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y111.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y112.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y113.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y114.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y115.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y116.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y117.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y12.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y120.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y13.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y14.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y146.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y147.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y148.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y15.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y153.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y154.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y155.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y156.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y157.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y158.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y159.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y16.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y160.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y161.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y162.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y163.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y164.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y165.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y166.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y167.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y168.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y169.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y17.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y170.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y18.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y180.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y181.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y182.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y183.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y184.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y185.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y186.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y187.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y188.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y19.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y192.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y193.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y194.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y195.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y2.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y20.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y21.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y22.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y23.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y24.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y242.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y243.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y244.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y245.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y246.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y247.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y248.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y249.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y25.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y250.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y251.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y252.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y253.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y254.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y255.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y256.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y257.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y258.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y259.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y26.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y27.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y28.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y29.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y3.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y30.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y31.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y32.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y33.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y34.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y35.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y36.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y37.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y38.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y39.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y4.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y40.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y41.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y42.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y44.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y45.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y46.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y47.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y49.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y50.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y51.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y52.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y53.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y54.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y55.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y56.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y58.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y59.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y6.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y60.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y61.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y62.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y65.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y66.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y67.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y69.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y7.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y70.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y71.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y73.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y74.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y75.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y76.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y77.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y78.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y79.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y8.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y81.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y82.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y85.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y86.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y89.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y9.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y90.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y91.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y92.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y92.png
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y95.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y96.jpg
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y97.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y98.JPG
#   inflating: /content/drive/MyDrive/KosarSadoughi/Dataset/yes/Y99.JPG

# %% [markdown]
# ### Loading Images

# %%
image_dir="../content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/"

# %% [markdown]
# ### Making directory for augmented images

# %% [markdown]
# **A directory is formed using os.makedirs() function for augmented images(yes/ no). Note- custom directory is obtained in outputs folder.**

# %%
os.makedirs('../content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/augmented-images')
os.makedirs('../content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/augmented-images/yes')
os.makedirs('../content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/augmented-images/no')

# %% [markdown]
# ## Augmentation of images
# **About the data:
# The dataset contains 2 folders: yes and no which contains 253 Brain MRI Images. The folder yes contains 155 Brain MRI Images that are tumorous andno contains 98 Brain MRI Images that are non-tumorous.**

# %%
def augment_data(file_dir, n_generated_samples, save_to_dir):
    data_gen = ImageDataGenerator(rotation_range=10, 
                                  width_shift_range=0.1, 
                                  height_shift_range=0.1, 
                                  shear_range=0.1, 
                                  brightness_range=(0.3, 1.0),
                                  horizontal_flip=True, 
                                  vertical_flip=True, 
                                  fill_mode='nearest'
                                 )

    for filename in listdir(file_dir):
        image = cv2.imread(file_dir + '/' + filename)
        # reshape the image
        image = image.reshape((1,)+image.shape)
        save_prefix = 'aug_' + filename[:-4]
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir,save_prefix=save_prefix, save_format='jpg'):
                i += 1
                if i > n_generated_samples:
                    break

# %%
augmented_data_path ='../content/drive/MyDrive/KosarSadoughi/Dataset/brain_tumor_dataset/augmented-images/'
# augment data for the examples with label equal to 'yes' representing tumurous examples
augment_data(file_dir=image_dir+'yes',n_generated_samples=6, save_to_dir=augmented_data_path+'yes')
# augment data for the examples with label equal to 'no' representing non-tumurous examples
augment_data(file_dir=image_dir+'no', n_generated_samples=9, save_to_dir=augmented_data_path+'no')

# %% [markdown]
# ## Preprocessing the data
#
# In order to crop the specific part of the image containing tumour,cropping technique via OpenCv is used, the details can be found here.[How to find extreme points in OpenCv?](https://www.pyimagesearch.com/2016/04/11/finding-extreme-points-in-contours-with-opencv/)

# %%
def crop_brain_contour(image, plot=False):
    
    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    # extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    
    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

    if plot:
        plt.figure()
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()
    
    return new_image

# %% [markdown]
# ## After applying the cropping function

# %%
ex_img = cv2.imread(image_dir+'yes/Y107.jpg')
ex_crop_img = crop_brain_contour(ex_img, True)

# %%
def load_data(dir_list, image_size):

    # load all images in a directory
    X = []
    y = []
    image_width, image_height = image_size
    
    for directory in dir_list:
        for filename in listdir(directory):
            image = cv2.imread(directory+'/'+filename)
            image = crop_brain_contour(image, plot=False)
            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            # normalize values
            image = image / 255.
            # convert image to numpy array and append it to X
            X.append(image)
            # append a value of 1 to the target array if the image
            # is in the folder named 'yes', otherwise append 0.
            if directory[-3:] == 'yes':
                y.append([1])
            else:
                y.append([0])
                
    X = np.array(X)
    y = np.array(y)
    
    # Shuffle the data
    X, y = shuffle(X, y)
    
    print(f'Number of examples is: {len(X)}')
    print(f'X shape is: {X.shape}')
    print(f'y shape is: {y.shape}')
    
    return X, y

# %%
augmented_yes =augmented_data_path+'yes'
augmented_no = augmented_data_path+'no'

IMG_WIDTH, IMG_HEIGHT = (240, 240)

X, y = load_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# Number of examples is: 2065
# X shape is: (2065, 240, 240, 3)
# y shape is: (2065, 1)

# %% [markdown]
# ## Visualization of data

# %%
def plot_sample_images(X, y, n=40):
    for label in [0,1]:
        # grab the first n images with the corresponding y values equal to label
        images = X[np.argwhere(y == label)]
        n_images = images[:n]
        
        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(10, 8))
        
        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])
            
            # remove ticks
            plt.tick_params(axis='both', which='both', 
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)
            
            i += 1
        
        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle(f"Brain Tumor: {label_to_str(label)}")
        plt.show()

# %%
plot_sample_images(X, y)

# %%
def split_data(X, y, test_size=0.2):
       
    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
# Out:
# number of training examples = 1445
# number of validation examples = 310
# number of test examples = 310

# %%
def build_model(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    
    X = Conv2D(32, (7, 7), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    
    X = MaxPooling2D((4, 4))(X) 
    X = MaxPooling2D((4, 4))(X) 
    X = Flatten()(X) 
    X = Dense(1, activation='sigmoid')(X) 
    model = Model(inputs = X_input, outputs = X)
    
    return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model=build_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  zero_padding2d (ZeroPadding  (None, 244, 244, 3)      0
#  2D)
#
#  conv2d (Conv2D)             (None, 238, 238, 32)      4736
#
#  bn0 (BatchNormalization)    (None, 238, 238, 32)      128
#
#  activation (Activation)     (None, 238, 238, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 59, 59, 32)       0
#  )
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 1)                 6273
#
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x=X_train, y=y_train, batch_size=32, epochs=22, validation_data=(X_val, y_val))
# Out:
# Epoch 1/22
# 46/46 [==============================] - 16s 87ms/step - loss: 0.6756 - accuracy: 0.6740 - val_loss: 0.6412 - val_accuracy: 0.6871
# Epoch 2/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.4346 - accuracy: 0.8000 - val_loss: 0.5965 - val_accuracy: 0.7613
# Epoch 3/22
# 46/46 [==============================] - 3s 63ms/step - loss: 0.3641 - accuracy: 0.8471 - val_loss: 0.5507 - val_accuracy: 0.7839
# Epoch 4/22
# 46/46 [==============================] - 3s 64ms/step - loss: 0.3561 - accuracy: 0.8519 - val_loss: 0.7128 - val_accuracy: 0.5290
# Epoch 5/22
# 46/46 [==============================] - 3s 61ms/step - loss: 0.2990 - accuracy: 0.8810 - val_loss: 0.5772 - val_accuracy: 0.6677
# Epoch 6/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.2990 - accuracy: 0.8727 - val_loss: 0.4014 - val_accuracy: 0.8387
# Epoch 7/22
# 46/46 [==============================] - 3s 58ms/step - loss: 0.2600 - accuracy: 0.9045 - val_loss: 0.4734 - val_accuracy: 0.7677
# Epoch 8/22
# 46/46 [==============================] - 3s 65ms/step - loss: 0.3224 - accuracy: 0.8685 - val_loss: 0.7377 - val_accuracy: 0.6742
# Epoch 9/22
# 46/46 [==============================] - 3s 61ms/step - loss: 0.2432 - accuracy: 0.8976 - val_loss: 0.3405 - val_accuracy: 0.8581
# Epoch 10/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.2591 - accuracy: 0.8927 - val_loss: 0.6409 - val_accuracy: 0.7323
# Epoch 11/22
# 46/46 [==============================] - 3s 58ms/step - loss: 0.1846 - accuracy: 0.9280 - val_loss: 0.3350 - val_accuracy: 0.8516
# Epoch 12/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.1763 - accuracy: 0.9433 - val_loss: 0.3381 - val_accuracy: 0.8710
# Epoch 13/22
# 46/46 [==============================] - 3s 66ms/step - loss: 0.1714 - accuracy: 0.9426 - val_loss: 0.3311 - val_accuracy: 0.8581
# Epoch 14/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.1762 - accuracy: 0.9398 - val_loss: 0.3565 - val_accuracy: 0.8581
# Epoch 15/22
# 46/46 [==============================] - 3s 58ms/step - loss: 0.2660 - accuracy: 0.8865 - val_loss: 1.0992 - val_accuracy: 0.6548
# Epoch 16/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.2966 - accuracy: 0.8747 - val_loss: 0.5328 - val_accuracy: 0.8194
# Epoch 17/22
# 46/46 [==============================] - 3s 61ms/step - loss: 0.1586 - accuracy: 0.9426 - val_loss: 0.6610 - val_accuracy: 0.7645
# Epoch 18/22
# 46/46 [==============================] - 3s 67ms/step - loss: 0.1933 - accuracy: 0.9204 - val_loss: 0.5284 - val_accuracy: 0.8000
# Epoch 19/22
# 46/46 [==============================] - 3s 58ms/step - loss: 0.1160 - accuracy: 0.9702 - val_loss: 0.3484 - val_accuracy: 0.8645
# Epoch 20/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.1150 - accuracy: 0.9619 - val_loss: 0.3509 - val_accuracy: 0.8677
# Epoch 21/22
# 46/46 [==============================] - 3s 60ms/step - loss: 0.1073 - accuracy: 0.9682 - val_loss: 0.5569 - val_accuracy: 0.7903
# Epoch 22/22
# 46/46 [==============================] - 3s 62ms/step - loss: 0.0878 - accuracy: 0.9758 - val_loss: 0.4051 - val_accuracy: 0.8516

# %%
history = model.history.history

# %% [markdown]
# ### Plotting of aaccuracy

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %%
plot_metrics(history)
